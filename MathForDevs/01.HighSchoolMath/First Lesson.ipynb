# %%
# %matplotlib inline

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
x_plot = np.linspace(-5, 5, 1000)
y_plot = 2 * x_plot + 3

# %%
plt.plot(x_plot, y_plot)
plt.show()
